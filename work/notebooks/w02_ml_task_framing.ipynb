# %% [markdown]
# <a href="https://colab.research.google.com/github/jetendarsoothar-png/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/jetendarsoothar-png/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*
#
# My lane is a ranking problem.
#
# The goal is to rank content pages so that the pages most worth reviewing appear first. The output supports a content-review queue, where higher-ranked pages receive attention before lower-ranked pages.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*
#
# The target/proxy is whether a content page is showing a decline in recent search visibility.
#
# For the starter dataset, the proxy target is `is_declining_label`, which equals 1 when `trend_direction == "down"` and 0 otherwise. This is an observed proxy based on the page's recent 30-day trend, not a future prediction.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*
#
# The success metric is Precision@K, using Precision@20 and Precision@50.
#
# A higher Precision@K means that more of the pages placed near the top of the review queue are actually relevant. This is useful because the content team has limited review capacity and needs the most useful pages near the top.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*
#
# One row represents one content item (page).
#
# The starter dataset contains one record for each pseudonymized content page. The columns describe that page's content properties and its observed search/engagement performance over the 90-day window.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import os

repo_path = "/content/flyrank-ml-internship-starter"

if not os.path.exists(repo_path):
    # !git clone https://github.com/flyrank-bih/flyrank-ml-internship-starter.git
else:
    print("Repository already exists. Skipping clone.")
# Out:
# Repository already exists. Skipping clone.

# %%
import os

print(os.listdir("/content/flyrank-ml-internship-starter"))
# Out:
# ['data', 'GUIDE.md', 'notebooks', 'submission', 'skills', 'DATA_USE.md', '.github', '.git', 'scripts', 'SETUP.md', 'requirements.txt', 'CLAUDE.md', 'outputs', 'LICENSE', 'README.md', 'docs', 'AGENTS.md', '.gitignore', 'work']

# %%
# !find /content/flyrank-ml-internship-starter -name "*.csv"
# Out:
# /content/flyrank-ml-internship-starter/data/raw/content_refresh_anonymized.csv
# /content/flyrank-ml-internship-starter/outputs/refresh_queue_sample.csv

# %%
import pandas as pd

df = pd.read_csv(
    "/content/flyrank-ml-internship-starter/data/raw/content_refresh_anonymized.csv"
)

df.head(10)
# Out:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
# 5  content_d4084a4bc775  client_f369cb89fc          720.0         1.00
# 6  content_9a34b442b552  client_8722616204            0.0         0.00
# 7  content_a63219c6e95a  client_19581e27de          590.0         0.44
# 8  content_5e6c160719bc  client_6208ef0f77            0.0         0.00
# 9  content_c27558df2b0c  client_19581e27de            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# ...

# %%
df["is_declining_label"] = (df["trend_direction"] == "down").astype(int)

df[["content_id", "trend_direction", "is_declining_label"]].head(10)
# Out:
#              content_id trend_direction  is_declining_label
# 0  content_304f48230142            down                   1
# 1  content_a1fb4e703a9e            down                   1
# 2  content_9aa793d4d895            down                   1
# 3  content_331d6c4de07b          stable                   0
# 4  content_d99b7a2d90ca            down                   1
# 5  content_d4084a4bc775            down                   1
# 6  content_9a34b442b552            down                   1
# 7  content_a63219c6e95a          stable                   0
# 8  content_5e6c160719bc            down                   1
# 9  content_c27558df2b0c            down                   1

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*
#
#
# A fixed rule might rank pages using one or two thresholds, such as impressions or average position. However, page performance depends on several signals at the same time, including impressions, clicks, sessions, CTR, average position, content age, freshness, and content properties.
#
# ML can learn how these signals work together instead of relying on one fixed threshold. The model can then produce a ranking score that helps prioritize which pages should be reviewed first.
#
# The action supported by the output is a ranked content-review queue: higher-priority pages can be reviewed before lower-priority pages.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [✅] Every section above is filled — markdown thinking AND the code that backs it
# - [✅] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [✅] No client names, URLs, or private queries anywhere
# - [✅] My claims use careful words: observed, measured, directional, decision-support
# - [✅] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
